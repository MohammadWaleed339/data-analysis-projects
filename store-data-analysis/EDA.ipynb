# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine, text
import logging
import os

# %%
conn = create_engine("mysql+mysqlconnector://root:Mysqlpswd%40123@localhost:3306/waleeddb")

# %%
tables = pd.read_sql_query("SELECT table_name FROM information_schema.tables WHERE table_schema = 'waleeddb'",conn)
tables
# Out:
#     TABLE_NAME
# 0    customers
# 1  order_items
# 2       orders
# 3      payment
# 4     products
# 5      reviews
# 6    shipments
# 7    suppliers

# %%
shipment_details = pd.read_sql_query('''SELECT 
                                            s.shipment_id,
                                            o.order_date,
                                            o.customer_id,
                                            o.total_price,
                                            s.shipment_date,
                                            s.carrier,
                                            s.delivery_date,
                                            s.shipment_status,
                                            oi.product_id
                                        FROM shipments s
                                        JOIN orders o
                                        ON s.order_id = o.order_id
                                        JOIN order_items oi
                                        ON oi.order_id = o.order_id
                                        ''', conn)

# %%
shipment_details
# Out:
#        shipment_id  order_date  customer_id  total_price shipment_date  \
# 0             1126  2023-11-17         4825       308.21    2023-11-22
# 1               57  2024-05-26          975       388.08    2024-05-28
# 2             1860  2024-09-30         4276        42.33    2024-10-02
# 3             2853  2024-03-29         1888        44.45    2024-04-01
# 4               51  2024-05-16         3177       735.84    2024-05-18
# ...            ...         ...          ...          ...           ...
# 19995          303  2024-06-16         9337      2770.23    2024-06-21
# 19996         7320  2024-06-10         1618       376.69    2024-06-12
# 19997        12569  2024-03-25         1827       431.91    2024-03-28
# 19998        14925  2024-02-26         1549      2434.97    2024-02-28
# 19999         4045  2023-11-19         9959      4701.44    2023-11-21
#
#       carrier delivery_date shipment_status  product_id
# 0         UPS    2023-11-24       Delivered        1461
# ...

# %%
for table in tables['TABLE_NAME']:
    print('-'*25,table,'-'*25)
    print(pd.read_sql(f"select count(*) from {table}",conn)['count(*)'][0])
    display(pd.read_sql(f"select * from {table} limit 5", conn))
# Out:
# ------------------------- customers -------------------------
# 10000
#    customer_id first_name last_name                       address  \
# 0            1      James     Smith  123 Main St, Springfield, IL
# 1            2      James   Johnson  123 Main St, Springfield, IL
# 2            3      James  Williams  123 Main St, Springfield, IL
# 3            4      James     Brown  123 Main St, Springfield, IL
# 4            5      James     Jones  123 Main St, Springfield, IL
#
#                      email  phone_number
# 0     jsmith1@customer.com  555-190-3233
# 1   jjohnson2@customer.com  555-525-8357
# 2  jwilliams3@customer.com  555-933-4447
# 3     jbrown4@customer.com  555-897-0326
# 4     jjones5@customer.com  555-762-5836
# ------------------------- final_table -------------------------
# 10696
#    customer_id  PricePaidPerCustomer  SumPriceAtPayment  product_id  \
# 0         9077              13151.44            2360.30        1577
# ...

# %%
# Get the most profitable products
premium_product = pd.read_sql_query('''SELECT 
                                            pd.product_id,
                                            pd.supplier_id,
                                            r.customer_id,
                                            AVG(r.rating) AS avg_rating,            
                                            AVG(oi.price_at_purchase) AS avg_price_at_purchase,
                                            oi.order_item_id,
                                            SUM(oi.quantity) AS TotalQuantity,
                                            pd.product_name,
                                            pd.category,
                                            pd.price
                                        FROM order_items oi
                                        RIGHT JOIN products pd ON oi.product_id = pd.product_id
                                        RIGHT JOIN reviews r ON pd.product_id = r.product_id
                                        WHERE oi.price_at_purchase > 0
                                        GROUP BY r.customer_id, pd.product_id, pd.product_name, pd.category, pd.price, pd.supplier_id,oi.order_item_id
                                        ORDER BY avg_price_at_purchase DESC;

''', conn)

# %%
premium_product
# Out:
#        product_id  supplier_id  customer_id  avg_rating  \
# 0            1577          577         9077         2.0
# 1            1577          577         1577         2.0
# 2            1577          577         7577         2.0
# 3            1577          577           77         2.0
# 4            1577          577         4577         2.0
# ...           ...          ...          ...         ...
# 10691        1547          547         7547         1.0
# 10692        1547          547           47         1.0
# 10693        1547          547         9047         1.0
# 10694        1547          547         6047         1.0
# 10695        1547          547         4547         1.0
#
#        avg_price_at_purchase  order_item_id  TotalQuantity  product_name  \
# 0                     999.54           5618            4.0   Smart Watch
# 1                     999.54           5618            4.0   Smart Watch
# ...

# %%
# get details of customers who is buying a lot
premium_customer = pd.read_sql_query(''' SELECT 
                                             c.customer_id,
                                             c.first_name,
                                             c.last_name,
                                             c.email,
                                             SUM(o.total_price) as SumOfTotalPrice,
                                             SUM(p.amount) as TotalPayment,
                                             AVG(r.rating) as AverageRating
                                         FROM customers c
                                         LEFT JOIN orders o
                                         ON c.customer_id = o.customer_id
                                         LEFT JOIN payment p
                                         ON o.order_id = p.order_id
                                         LEFT JOIN reviews r
                                         ON r.customer_id = c.customer_id
                                         GROUP BY c.customer_id, c.first_name, c.last_name, c.email
                                         ORDER BY SumOfTotalPrice  desc
                                ''', conn)

# %%
premium_customer
# Out:
#       customer_id first_name  last_name                        email  \
# 0            4540       Mary    Abigail    mabigail4540@customer.com
# 1              14      James     Wilson       jwilson14@customer.com
# 2            6003       Mary      Roger      mroger6003@customer.com
# 3              36      James  Christina    jchristina36@customer.com
# 4            6050       Mary       Anna       manna6050@customer.com
# ...           ...        ...        ...                          ...
# 9995         8972       John      Lopez      jlopez8972@customer.com
# 9996         2104      James      Brown      jbrown2104@customer.com
# 9997         5426       Mary  Christina  mchristina5426@customer.com
# 9998         5894       Mary     Wilson     mwilson5894@customer.com
# 9999         5678       Mary      Davis      mdavis5678@customer.com
#
#       SumOfTotalPrice  TotalPayment  AverageRating
# 0            31605.44       2458.44            2.0
# ...

# %%
final_table = pd.read_sql_query(''' WITH customer_table AS (SELECT 
                                                                 c.customer_id,
                                                                 c.first_name,
                                                                 c.last_name,
                                                                 c.email,
                                                                 SUM(o.total_price) as LifeTimeCustomerValue,
                                                                 SUM(p.amount) as LifeTimePayment,
                                                                 AVG(r.rating) as AverageRating
                                                             FROM customers c
                                                             LEFT JOIN orders o
                                                             ON c.customer_id = o.customer_id
                                                             LEFT JOIN payment p
                                                             ON o.order_id = p.order_id
                                                             LEFT JOIN reviews r
                                                             ON r.customer_id = c.customer_id
                                                             GROUP BY c.customer_id, c.first_name, c.last_name, c.email
                                                             ORDER BY LifeTimeCustomerValue  desc),
                                            
                                            order_table AS (SELECT 
                                                                pd.product_id,
                                                                pd.supplier_id,
                                                                r.customer_id,
                                                                AVG(r.rating) AS avg_rating,            
                                                                AVG(oi.price_at_purchase) AS AvgItemPriceAtPurchase,
                                                                oi.order_item_id,
                                                                SUM(oi.quantity) AS TotalQuantity,
                                                                pd.product_name,
                                                                pd.category,
                                                                pd.price
                                                            FROM order_items oi
                                                            RIGHT JOIN products pd ON oi.product_id = pd.product_id
                                                            RIGHT JOIN reviews r ON pd.product_id = r.product_id
                                                            WHERE oi.price_at_purchase > 0
                                                            GROUP BY r.customer_id, pd.product_id, pd.product_name, pd.category, pd.price, pd.supplier_id,oi.order_item_id
                                                            ORDER BY AvgItemPriceAtPurchase DESC),
                                          shipment_table AS (SELECT 
                                                                s.shipment_id,
                                                                o.order_date,
                                                                o.customer_id,
                                                                o.total_price,
                                                                s.shipment_date,
                                                                s.carrier,
                                                                s.delivery_date,
                                                                s.shipment_status,
                                                                oi.product_id
                                                            FROM shipments s
                                                            JOIN orders o
                                                            ON s.order_id = o.order_id
                                                            JOIN order_items oi
                                                            ON oi.order_id = o.order_id
                                                            )
                                        SELECT 
                                            ot.product_id,
                                            ot.supplier_id,
                                            ct.customer_id,
                                            ct.LifeTimeCustomerValue,
                                            ct.LifeTimePayment,
                                            st.carrier,
                                            ot.avg_rating,
                                            ot.AvgItemPriceAtPurchase,
                                            ot.TotalQuantity,
                                            ot.product_name,
                                            st.delivery_date,
                                            shipment_date,
                                            ot.category,
                                            st.shipment_status,
                                            ot.price AS ShippedProductPrice
                                        FROM customer_table ct
                                        RIGHT JOIN order_table ot
                                        ON ot.customer_id = ct.customer_id
                                        JOIN shipment_table st
                                        ON st.customer_id = ot.customer_id
                                        
                                        
                                                            ''',conn)
final_table
# Out:
#        product_id  supplier_id  customer_id  LifeTimeCustomerValue  \
# 0              52          552         4552               15221.38
# 1              52          552         4552               15221.38
# 2            1552          552         4552               15221.38
# 3            1552          552         4552               15221.38
# 4              52          552         4552               15221.38
# ...           ...          ...          ...                    ...
# 21381          49          549         1549                6790.58
# 21382          49          549         1549                6790.58
# 21383          49          549         1549                6790.58
# 21384          49          549         1549                6790.58
# 21385          49          549         1549                6790.58
#
#        LifeTimePayment carrier  avg_rating  AvgItemPriceAtPurchase  \
# 0              1464.24     DHL         2.0                  861.68
# ...

# %%
pd.read_sql_query('''DROP TABLE IF EXISTS final_table''',conn)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 pd.read_sql_query('''DROP TABLE IF EXISTS final_table''',conn)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# ...

# %%
table_query = ''' CREATE TABLE final_table (customer_id INT, 
                                            product_id INT,
                                            supplier_id INT,
                                            LifeTimeCustomerValue FLOAT,
                                            LifeTimePayment FLOAT,
                                            avg_rating INT,
                                            AvgItemPriceAtPurchase FLOAT,
                                            carrier VARCHAR(10),
                                            TotalQuantity INT,
                                            product_name VARCHAR(20),
                                            delivery_date DATE,
                                            shipment_date DATE,
                                            category VARCHAR(20),
                                            shipment_status VARCHAR(20),
                                            ProductPrice FLOAT,
                                            PRIMARY KEY(customer_id,product_id))
                                            '''

# %%
with conn.connect() as connection:
    result = connection.execute(text(table_query))

# %%
pd.read_sql_query(''' SELECT * from final_table''',conn)
# Out:
# Empty DataFrame
# Columns: [customer_id, product_id, supplier_id, LifeTimeCustomerValue, LifeTimePayment, avg_rating, AvgItemPriceAtPurchase, carrier, TotalQuantity, product_name, delivery_date, shipment_date, category, shipment_status, ProductPrice]
# Index: []

# %%
final_table.to_sql('final_table',conn, if_exists = "replace", index = False)
# Out:
# 21386
